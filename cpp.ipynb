// %%
#include <iostream>
std::cout << "Hello from Cling!" << std::endl;
// Out:
// In file included from input_line_4:2:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/iostream:42:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/ios:218:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__fwd/ios.h:13:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__fwd/string.h:13:
// /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__fwd/memory.h:18:1: error: namespaces can only be defined in global or namespace scope
// _LIBCPP_BEGIN_NAMESPACE_STD
// ^
// /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__config:596:85: note: expanded from macro '_LIBCPP_BEGIN_NAMESPACE_STD'
//                                       namespace _LIBCPP_TYPE_VISIBILITY_DEFAULT std {                                  \
// ...
