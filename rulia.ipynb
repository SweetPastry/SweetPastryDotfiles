# %%
using Pkg
Pkg.add("Plots")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
using Plots

x = 0:0.1:2π       # 横坐标
y = sin.(x)         # 纵坐标（注意 `.` 是广播）

plot(x, y, label="sin(x)", title="Plot of sin(x)", xlabel="x", ylabel="sin(x)", lw=2)

# %%
gr()          # 默认高效后端
# pyplot()    # 如果你喜欢 matplotlib 风格（需要额外安装）
# Out:
# Plots.GRBackend()
