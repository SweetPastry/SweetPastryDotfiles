# %%
(* 波兰前缀法, 抽象语法树, 计算机理解表达式的方法正好和人类相反 *)
TreeForm[(a+b)^2/z==x]
# Out:
# Equal[|                                        , x]
#       Times[|                   , |           ]
#             Power[|         , 2]  Power[z, -1]
#                   Plus[a, b]
