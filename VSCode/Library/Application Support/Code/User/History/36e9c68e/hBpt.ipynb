# %%
(* 波兰前缀法, 抽象语法树, 计算机理解表达式的方法正好和人类相反 *)
(* Lisp 语言. 古董 *)
TreeForm[(a-b^n)/z==x]
(* 计算机是如何处理 - 和 / 的, 看图 *)
# Out:
# Equal[|                                                   , x]
#       Times[|                              , |           ]
#             Plus[a, |                     ]  Power[z, -1]
#                     Times[-1, |          ]
#                               Power[b, n]
