# %%
(* 波兰前缀法, 抽象语法树, 计算机理解表达式的方法正好和人类相反 *)
(* Lisp 语言. 古董 *)
TreeForm[(a+b^n)/z==x]
# Out:
# Equal[|                                        , x]
#       Times[|                   , |           ]
#             Plus[a, |          ]  Power[z, -1]
#                     Power[b, n]
