% %%
data=[randn(2,5),randn(2,3)+ones(2,3)*10];
plot(data(1,:),data(2,:),'bo')
% Out:
% data =
%
%   Columns 1 through 3
%
%          -1.20748692268504          1.63023528916473          1.03469300991786
%          0.717238651328838         0.488893770311789         0.726885133383238
%
%   Columns 4 through 6
%
%         -0.303440924786016        -0.787282803758638          8.85292989303085
%          0.293871467096658         0.888395631757642          8.93112954183197
%
%   Columns 7 through 8
%
%           9.19050130557512          11.4383802928151
%            7.0557158380051          10.3251905394562
