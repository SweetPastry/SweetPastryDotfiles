# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
data = np.loadtxt("Bol.csv", delimiter=",", dtype=str)
TF = data[:, 0]
theta = data[:, 1]
phi = data[:, 2]

# %%
plt.plot(TF, theta)
