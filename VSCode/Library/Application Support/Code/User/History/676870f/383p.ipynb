# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
data = np.loadtxt("Bol.csv", delimiter=",", dtype=str)
TF = data[:, 0]
theta = data[:, 1]
phi = data[:, 2]

omega = 2*np.pi/TF
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 theta = data[:, 1]
#       4 phi = data[:, 2]
# ----> 6 omega = 2*np.pi/TF
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
print(TF)
print(theta)
print(phi)
# Out:
# ['1540' '1550' '1558' '1565' '1570' '1575' '1579' '1582' '1584' '1586'
#  '1588' '1589' '1592' '1595' '1598' '1603' '1610' '1620' '1630' '1645'
#  '1660']
# ['50' '60' '69' '83' '95.5' '115' '125' '132' '134' '134' '135' '135'
#  '131.5' '129.5' '124' '117.5' '106' '90' '76' '62' '53']
# ['162' '157' '151.4' '146.2' '138.6' '127' '115' '104.8' '100' '95' '90'
#  '87.8' '82.1' '80.1' '69.9' '61.1' '53.7' '44.4' '36' '29.3' '26.3']

# %%
plt.plot(TF, theta)

# %%
plt.plot(TF, phi)
