% %%
t = linspace(0, 1, 1000)
% Out:
% t =
%
%   Columns 1 through 3
%
%                          0         0.001001001001001         0.002002002002002
%
%   Columns 4 through 6
%
%          0.003003003003003         0.004004004004004         0.005005005005005
%
%   Columns 7 through 9
%
%        0.00600600600600601       0.00700700700700701       0.00800800800800801
%
%   Columns 10 through 12
%
%        0.00900900900900901          0.01001001001001         0.011011011011011
%
%   Columns 13 through 15
%
%          0.012012012012012         0.013013013013013         0.014014014014014
%
%   Columns 16 through 18
%
%          0.015015015015015         0.016016016016016         0.017017017017017
%
%   Columns 19 through 21
%
%          0.018018018018018         0.019019019019019          0.02002002002002
%
%   Columns 22 through 24
%
%          0.021021021021021         0.022022022022022         0.023023023023023
%
%   Columns 25 through 27
%
%          0.024024024024024         0.025025025025025         0.026026026026026
% ...

% %%
x = 2*sin(t)
% Out:
% x =
%
%   Columns 1 through 3
%
%                          0       0.00200200166766668       0.00400400132932185
%
%   Columns 4 through 6
%
%        0.00600599697895599       0.00800798661056361        0.0100099682181453
%
%   Columns 7 through 9
%
%         0.0120119397957095        0.0140138993372751        0.0160158448368725
%
%   Columns 10 through 12
%
%         0.0180177742885467        0.0200196856863584        0.0220215770243865
%
%   Columns 13 through 15
%
%         0.0240234462967302        0.0260252914975106        0.0280271106208728
%
%   Columns 16 through 18
%
%         0.0300289016609884        0.0320306626120568        0.0340323914683078
%
%   Columns 19 through 21
%
%         0.0360340862240031        0.0380357448734387         0.040037365410947
%
%   Columns 22 through 24
%
%         0.0420389458308981        0.0440404841277028        0.0460419782958138
%
%   Columns 25 through 27
%
%          0.048043426329728        0.0500448262239888        0.0520461759731875
% ...

% %%
% 
plot(t, x)
