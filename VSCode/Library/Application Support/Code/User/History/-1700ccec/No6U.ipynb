% %%
U = -2:0.5:0
% Out:
% U =
%
%   Columns 1 through 3
%
%                         -2                      -1.5                        -1
%
%   Columns 4 through 5
%
%                       -0.5                         0

% %%
I = [-1.1, -0.9, -0.6, -0.6, -0.6]
% Out:
% I =
%
%   Columns 1 through 3
%
%                       -1.1                      -0.9                      -0.6
%
%   Columns 4 through 5
%
%                       -0.6                      -0.6

% %%
plot(U, I)
