% %%
U = -2:0.5:0
% Out:
% U =
%
%   Columns 1 through 3
%
%                         -2                      -1.5                        -1
%
%   Columns 4 through 5
%
%                       -0.5                         0

% %%
I = [-1.1, -0.9, -0.6, -0.6, -0.6]
% Out:
% I =
%
%   Columns 1 through 3
%
%                       -1.1                      -0.9                      -0.6
%
%   Columns 4 through 5
%
%                       -0.6                      -0.6

% %%
plot(U, I)

% %%
VV = [-1, 1, 3, 5, 7, 12, 20, 30, 40, 50]
II = [-1, 0, 1.2, 2, 3.0, 5.3, 8.4, 8.8, 9.3, 9.1]
% Out:
% VV =
%
%     -1     1     3     5     7    12    20    30    40    50
%
%
% II =
%
%   Columns 1 through 3
%
%                         -1                         0                       1.2
%
%   Columns 4 through 6
%
%                          2                         3                       5.3
%
%   Columns 7 through 9
%
%                        8.4                       8.8                       9.3
%
%   Column 10
%
%                        9.1

% %%
plot(VV, II)

% %%
VVV = cat(U, VV)
% Out:
% Error using cat
% Dimension argument must be a real, positive, integer scalar.
