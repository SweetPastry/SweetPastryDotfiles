% %%
U = -2:0.5:0
% Out:
% U =
%
%   Columns 1 through 3
%
%                         -2                      -1.5                        -1
%
%   Columns 4 through 5
%
%                       -0.5                         0

% %%
I = [-1.1, -0.9, -0.6, -0.6, -0.6]
% Out:
% I =
%
%   Columns 1 through 3
%
%                       -1.1                      -0.9                      -0.6
%
%   Columns 4 through 5
%
%                       -0.6                      -0.6

% %%
plot(U, I)

% %%
VV = [-1, 1, 3, 5, 7, 12, 20, 30, 40, 50]
II = [-1, 0, 1.2, 2, 3.0, 5.3, 8.4, 8.8, 9.3, 9.1]
% Out:
% VV =
%
%     -1     1     3     5     7    12    20    30    40    50
%
%
% II =
%
%   Columns 1 through 3
%
%                         -1                         0                       1.2
%
%   Columns 4 through 6
%
%                          2                         3                       5.3
%
%   Columns 7 through 9
%
%                        8.4                       8.8                       9.3
%
%   Column 10
%
%                        9.1

% %%
plot(VV, II)

% %%
VVV = [U, VV]
III = [I, II]
plot(VVV, III)
% Out:
% VVV =
%
%   Columns 1 through 3
%
%                         -2                      -1.5                        -1
%
%   Columns 4 through 6
%
%                       -0.5                         0                        -1
%
%   Columns 7 through 9
%
%                          1                         3                         5
%
%   Columns 10 through 12
%
%                          7                        12                        20
%
%   Columns 13 through 15
%
%                         30                        40                        50
%
%
% III =
%
%   Columns 1 through 3
%
%                       -1.1                      -0.9                      -0.6
%
%   Columns 4 through 6
%
%                       -0.6                      -0.6                        -1
%
%   Columns 7 through 9
%
%                          0                       1.2                         2
%
%   Columns 10 through 12
%
% ...

% %%
lambda = 400:40:600;
nu = 1./lambda;
V = [-1.588, -1.308, -1.078, -0.878, -0.702, -0.582];
plot(nu, V)
