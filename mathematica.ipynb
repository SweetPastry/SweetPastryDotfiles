# %%
ComplexPlot[Sqrt[z], {z, -2 - 2 I, 2 + 2 I}]
# Out:
# -Graphics-

# %%
ReImSurface[f_] := 
  ParametricPlot3D[
    {Re[z], Im[z], Re[f[z]]},
    {r, 0.01, 2}, {θ, 0, 2 Pi},
    PlotPoints -> 100,
    Mesh -> None,
    ColorFunction -> Function[{x, y, z}, ColorData["Rainbow"][θ/(2 Pi)]],
    ColorFunctionScaling -> False,
    Boxed -> False
  ] /. z -> r Exp[I θ]

ReImSurface[Sqrt]
# Out:
# -Graphics3D-

# %%
ComplexPlot3D[Abs[Log[z]], {z, -3 - 3 I, 3 + 3 I}]
# Out:
# -Graphics3D-
